# %%
import pandas as pd

# Load the data
data = pd.read_csv('Pictures/telegram_text_data1.txt')

# %%
# Display the first few rows
print(data.head())

# Get basic info about the DataFrame
print(data.info())

# Check for missing values
print(data.isnull().sum())
# Out:
#   Channel Title         Channel Username  Message ID  \
# 0   EthioBrand®  @ethio_brand_collection        5779
# 1   EthioBrand®  @ethio_brand_collection        5778
# 2   EthioBrand®  @ethio_brand_collection        5777
# 3   EthioBrand®  @ethio_brand_collection        5776
# 4   EthioBrand®  @ethio_brand_collection        5775
#
#                                         Message Text  \
# 0  Puma CA pro classic\r\nSize 40,41,42,43\r\nPri...
# 1  Goupu lace comfort\r\nSize 39,40,41,42,43,44\r...
# 2  Chelsea 05 half boots leather\r\nSize 39,40,41...
# 3  Nike FC classic \r\nSize 40,41,42,43\r\nPrice ...
# 4  Goupu leather comfort\r\nSize 39,40,41,42,43,4...
#
#                 Message Date
# 0  2024-09-26 09:04:41+00:00
# 1  2024-09-26 06:20:06+00:00
# 2  2024-09-25 09:07:20+00:00
# 3  2024-09-25 06:15:19+00:00
# 4  2024-09-24 09:01:56+00:00
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2771 entries, 0 to 2770
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Channel Title     2771 non-null   object
#  1   Channel Username  2771 non-null   object
#  2   Message ID        2771 non-null   int64
#  3   Message Text      2771 non-null   object
#  4   Message Date      2771 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 108.4+ KB
# None
# Channel Title       0
# Channel Username    0
# Message ID          0
# Message Text        0
# Message Date        0
# dtype: int64

# %%
data['Message Date'] = pd.to_datetime(data['Message Date'])

# %%
import pandas as pd
df = pd.DataFrame(data)

# Cleaning steps
# 1. Trim Whitespaces
df['Channel Title'] = df['Channel Title'].str.strip()
df['Channel Username'] = df['Channel Username'].str.strip()
df['Message Text'] = df['Message Text'].str.strip()

# 2. Handle Special Characters
df['Channel Title'] = df['Channel Title'].str.replace('®', '', regex=False)

# 3. Standardize Date Formats
df['Message Date'] = pd.to_datetime(df['Message Date']).dt.strftime('%Y-%m-%d %H:%M:%S')

# 4. Remove Duplicate Entries
df.drop_duplicates(subset=['Message ID'], inplace=True)

# 5. Normalize Text Fields
df['Message Text'] = df['Message Text'].str.lower()

# 6. (Optional) Extract price from Message Text
df['Price'] = df['Message Text'].str.extract(r'Price (\d+ birr)')[0]

# Display cleaned DataFrame
print(df)
# Out:
#      Channel Title         Channel Username  Message ID  \
# 0       EthioBrand  @ethio_brand_collection        5779
# 1       EthioBrand  @ethio_brand_collection        5778
# 2       EthioBrand  @ethio_brand_collection        5777
# 3       EthioBrand  @ethio_brand_collection        5776
# 4       EthioBrand  @ethio_brand_collection        5775
# ...            ...                      ...         ...
# 2766    EthioBrand  @ethio_brand_collection          52
# 2767    EthioBrand  @ethio_brand_collection          51
# 2768    EthioBrand  @ethio_brand_collection          50
# 2769    EthioBrand  @ethio_brand_collection          49
# 2770    EthioBrand  @ethio_brand_collection          48
#
#                                            Message Text         Message Date  \
# 0     puma ca pro classic\r\nsize 40,41,42,43\r\npri...  2024-09-26 09:04:41
# 1     goupu lace comfort\r\nsize 39,40,41,42,43,44\r...  2024-09-26 06:20:06
# 2     chelsea 05 half boots leather\r\nsize 39,40,41...  2024-09-25 09:07:20
# 3     nike fc classic \r\nsize 40,41,42,43\r\nprice ...  2024-09-25 06:15:19
# 4     goupu leather comfort\r\nsize 39,40,41,42,43,4...  2024-09-24 09:01:56
# ...                                                 ...                  ...
# 2766  ladies nike \r\nmade in vietnam\r\nsize 38\r\n...  2017-08-03 09:58:46
# 2767  ፧ ተሽጦ አልቋል\r\nnike kobe 11\r\nmade in vietnam\...  2017-08-03 09:58:46
# 2768  nike airmax flyknite\r\nmade in vietnam\r\nsiz...  2017-08-03 09:58:46
# 2769  nike airmax flyknite\r\nmade in vietnam\r\nsiz...  2017-08-03 09:58:46
# 2770  nike airmax tailwind \r\nmade in vietnam\r\nsi...  2017-08-03 09:58:45
#
#      Price
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ...    ...
# 2766   NaN
# 2767   NaN
# 2768   NaN
# 2769   NaN
# 2770   NaN
#
# [2771 rows x 6 columns]

# %%
df
# Out:
#      Channel Title         Channel Username  Message ID  \
# 0       EthioBrand  @ethio_brand_collection        5779
# 1       EthioBrand  @ethio_brand_collection        5778
# 2       EthioBrand  @ethio_brand_collection        5777
# 3       EthioBrand  @ethio_brand_collection        5776
# 4       EthioBrand  @ethio_brand_collection        5775
# ...            ...                      ...         ...
# 2766    EthioBrand  @ethio_brand_collection          52
# 2767    EthioBrand  @ethio_brand_collection          51
# 2768    EthioBrand  @ethio_brand_collection          50
# 2769    EthioBrand  @ethio_brand_collection          49
# 2770    EthioBrand  @ethio_brand_collection          48
#
#                                            Message Text         Message Date  \
# 0     puma ca pro classic\r\nsize 40,41,42,43\r\npri...  2024-09-26 09:04:41
# 1     goupu lace comfort\r\nsize 39,40,41,42,43,44\r...  2024-09-26 06:20:06
# 2     chelsea 05 half boots leather\r\nsize 39,40,41...  2024-09-25 09:07:20
# 3     nike fc classic \r\nsize 40,41,42,43\r\nprice ...  2024-09-25 06:15:19
# 4     goupu leather comfort\r\nsize 39,40,41,42,43,4...  2024-09-24 09:01:56
# ...                                                 ...                  ...
# 2766  ladies nike \r\nmade in vietnam\r\nsize 38\r\n...  2017-08-03 09:58:46
# 2767  ፧ ተሽጦ አልቋል\r\nnike kobe 11\r\nmade in vietnam\...  2017-08-03 09:58:46
# 2768  nike airmax flyknite\r\nmade in vietnam\r\nsiz...  2017-08-03 09:58:46
# 2769  nike airmax flyknite\r\nmade in vietnam\r\nsiz...  2017-08-03 09:58:46
# 2770  nike airmax tailwind \r\nmade in vietnam\r\nsi...  2017-08-03 09:58:45
#
#      Price
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ...    ...
# 2766   NaN
# 2767   NaN
# 2768   NaN
# 2769   NaN
# 2770   NaN
#
# [2771 rows x 6 columns]

# %%
df['Message Text'].head()
# Out:
# 0    puma ca pro classic\r\nsize 40,41,42,43\r\npri...
# 1    goupu lace comfort\r\nsize 39,40,41,42,43,44\r...
# 2    chelsea 05 half boots leather\r\nsize 39,40,41...
# 3    nike fc classic \r\nsize 40,41,42,43\r\nprice ...
# 4    goupu leather comfort\r\nsize 39,40,41,42,43,4...
# Name: Message Text, dtype: object

# %%
df.to_csv('Pictures/ethio_brand_data_cleaned.csv', index=False)

# %%
# Load data into a DataFrame
df = pd.read_csv( )

# Define the characters to remove
special_characters_pattern = r'[📌✅🏢⚠️❌🆕#🎁❎"]'

# Clean the Message Text
df['Message Text'] = df['Message Text'].str.replace('\n', ' ').str.replace(special_characters_pattern, '', regex=True).str.strip()

# Save the cleaned DataFrame to a CSV file
df.to_csv('Pictures/2_ethio_brand_data_cleaned.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Load data into a DataFrame
# ----> 2 df = pd.read_csv( )
#       4 # Define the characters to remove
#       5 special_characters_pattern = r'[📌✅🏢⚠️❌🆕#🎁❎"]'
#
# TypeError: read_csv() missing 1 required positional argument: 'filepath_or_buffer'

# %%
import pandas as pd
from io import StringIO  # Make sure to import StringIO

# %%
import pandas as pd
import re  # Import the regular expressions module

# Assuming you've already loaded your DataFrame into df
# For example:
# df = pd.read_csv('your_file.csv')

# Define the special characters you want to remove
special_characters_pattern = r'[📌✅🏢⚠️❌🆕#🎁❎🌻🌼‼ እሁድ ሁሌም ክፍት ነን or call🌟📱👔|👖\(አዲስ የገባ\)"]'

# Remove special characters from the 'Message Text' column
df['Message Text'] = df['Message Text'].apply(lambda x: re.sub(special_characters_pattern, '', str(x)))

# Optionally, you can save the cleaned data back to CSV
df.to_csv('cleaned_file.csv', index=False)

# View the cleaned DataFrame
print(df.head())
# Out:
#   Channel Title         Channel Username  Message ID  \
# 0    EthioBrand  @ethio_brand_collection        5779
# 1    EthioBrand  @ethio_brand_collection        5778
# 2    EthioBrand  @ethio_brand_collection        5777
# 3    EthioBrand  @ethio_brand_collection        5776
# 4    EthioBrand  @ethio_brand_collection        5775
#
#                                         Message Text         Message Date  \
# 0  pumpssi\r\nsize40,41,42,43\r\npie3400bi\r\nራሻ-...  2024-09-26 09:04:41
# 1  gupuemft\r\nsize39,40,41,42,43,44\r\npie3500bi...  2024-09-26 06:20:06
# 2  hese05hfbtsethe\r\nsize39,40,41,42,43\r\npie40...  2024-09-25 09:07:20
# 3  nikefssi\r\nsize40,41,42,43\r\npie3300bi\r\nራሻ...  2024-09-25 06:15:19
# 4  gupuethemft\r\nsize39,40,41,42,43,44\r\npie350...  2024-09-24 09:01:56
#
#    Price
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
# Save the cleaned DataFrame to a CSV file
df.to_csv('Pictures/2_ethio_brand_data_cleaned.csv', index=False)

# %%
import pandas as pd
import re

# Load the CSV file
df = pd.read_csv('Pictures/2_ethio_brand_data_cleaned.csv')

# Define a pattern to remove only the specified unwanted phrases
specific_phrases_pattern = r'(@sofonias12|‼ እሁድ ሁሌም ክፍት ነን ‼|or call)'

# Clean the 'Message Text' column by removing the specified phrases
df['Message Text'] = df['Message Text'].apply(lambda x: re.sub(specific_phrases_pattern, '', str(x)))

# Remove any extra whitespace that may have been left behind
df['Message Text'] = df['Message Text'].str.strip()

# Save the cleaned data back to CSV
df.to_csv('Pictures/3_ethio_brand_data_cleaned.csv', index=False)

# Display the cleaned data
print(df.head())
# Out:
#   Channel Title         Channel Username  Message ID  \
# 0    EthioBrand  @ethio_brand_collection      5779.0
# 1    EthioBrand  @ethio_brand_collection      5778.0
# 2    EthioBrand  @ethio_brand_collection      5777.0
# 3    EthioBrand  @ethio_brand_collection      5776.0
# 4    EthioBrand  @ethio_brand_collection      5775.0
#
#                                         Message Text         Message Date  \
# 0  puma ca pro classic\r\nsize 40,41,42,43\r\npri...  2024-09-26 09:04:41
# 1  goupu lace comfort\r\nsize 39,40,41,42,43,44\r...  2024-09-26 06:20:06
# 2  chelsea 05 half boots leather\r\nsize 39,40,41...  2024-09-25 09:07:20
# 3  nike fc classic \r\nsize 40,41,42,43\r\nprice ...  2024-09-25 06:15:19
# 4  goupu leather comfort\r\nsize 39,40,41,42,43,4...  2024-09-24 09:01:56
#
#    Price
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
df = pd.read_csv('Pictures/2_ethio_brand_data_cleaned.csv')

# %%
data= df['Message Text']

# %%
data.head()
# Out:
# 0    puma ca pro classic\r\nsize 40,41,42,43\r\npri...
# 1    goupu lace comfort\r\nsize 39,40,41,42,43,44\r...
# 2    chelsea 05 half boots leather\r\nsize 39,40,41...
# 3    nike fc classic \r\nsize 40,41,42,43\r\nprice ...
# 4    goupu leather comfort\r\nsize 39,40,41,42,43,4...
# Name: Message Text, dtype: object

# %%
df = pd.DataFrame(data)

# Adjust pandas option to prevent truncation
pd.set_option('display.max_colwidth', None)

# Now display the full content
df.head()
# Out:
#                                                                                                                                                                                                      Message Text
# 0               puma ca pro classic\r\nsize 40,41,42,43\r\nprice 3400 birr\r\nአድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243\r\n                                    ethiobrand
# 1          goupu lace comfort\r\nsize 39,40,41,42,43,44\r\nprice 3500 birr\r\nአድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243\r\n                                    ethiobrand
# 2  chelsea 05 half boots leather\r\nsize 39,40,41,42,43\r\nprice 4000 birr\r\nአድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243\r\n                                    ethiobrand
# 3                  nike fc classic \r\nsize 40,41,42,43\r\nprice 3300 birr\r\nአድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243\r\n                                    ethiobrand
# 4       goupu leather comfort\r\nsize 39,40,41,42,43,44\r\nprice 3500 birr\r\nአድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243\r\n                                    ethiobrand

# %%
# Split the 'Message Text' into multiple columns using string methods
df['Product Name'] = df['Message Text'].str.split('\r\n').str[0]
df['Size'] = df['Message Text'].str.extract(r'size ([\d,]+)')
df['Price'] = df['Message Text'].str.extract(r'price (\d+ birr)')
df['Address'] = df['Message Text'].str.extract(r'አድራሻ-(.*) or call')
df['Phone'] = df['Message Text'].str.extract(r'or call (\d+)')

# Display the resulting DataFrame
pd.set_option('display.max_colwidth', None)  # To show the full content of columns
print(df[['Product Name', 'Size', 'Price', 'Address', 'Phone']])
# Out:
#                        Product Name               Size      Price  \
# 0               puma ca pro classic        40,41,42,43  3400 birr
# 1                goupu lace comfort  39,40,41,42,43,44  3500 birr
# 2     chelsea 05 half boots leather     39,40,41,42,43  4000 birr
# 3                  nike fc classic         40,41,42,43  3300 birr
# 4             goupu leather comfort  39,40,41,42,43,44  3500 birr
# ...                             ...                ...        ...
# 2753           nike airmax flyknite                 42  1250 birr
# 2754                            NaN                NaN        NaN
# 2755                            NaN                NaN        NaN
# 2756                            NaN                NaN        NaN
# 2757                            NaN                NaN        NaN
#
#                                                        Address       Phone
# 0     ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል  0920238243
# 1     ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል  0920238243
# 2     ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል  0920238243
# 3     ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል  0920238243
# 4     ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል  0920238243
# ...                                                        ...         ...
# 2753                                                       NaN         NaN
# 2754                                                       NaN         NaN
# 2755                                                       NaN         NaN
# 2756                                                       NaN         NaN
# 2757                                                       NaN         NaN
#
# [2758 rows x 5 columns]

# %%
df
# Out:
#                                                                                                                                                                                                         Message Text  \
# 0                  puma ca pro classic\r\nsize 40,41,42,43\r\nprice 3400 birr\r\nአድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243\r\n                                    ethiobrand
# 1             goupu lace comfort\r\nsize 39,40,41,42,43,44\r\nprice 3500 birr\r\nአድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243\r\n                                    ethiobrand
# 2     chelsea 05 half boots leather\r\nsize 39,40,41,42,43\r\nprice 4000 birr\r\nአድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243\r\n                                    ethiobrand
# 3                     nike fc classic \r\nsize 40,41,42,43\r\nprice 3300 birr\r\nአድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243\r\n                                    ethiobrand
# 4          goupu leather comfort\r\nsize 39,40,41,42,43,44\r\nprice 3500 birr\r\nአድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243\r\n                                    ethiobrand
# ...                                                                                                                                                                                                              ...
# 2753                                                   nike airmax flyknite\r\nmade in vietnam\r\nsize 42\r\nprice 1250 birr\r\n,2017-08-03 09:58:46,\r\nEthioBrand,@ethio_brand_collection,48,nike airmax tailwind
# 2754                                                                                                                                                                                                             NaN
# 2755                                                                                                                                                                                                             NaN
# 2756                                                                                                                                                                                                             NaN
# 2757                                                                                                                                                                                                             NaN
#
#                        Product Name               Size      Price  \
# 0               puma ca pro classic        40,41,42,43  3400 birr
# 1                goupu lace comfort  39,40,41,42,43,44  3500 birr
# 2     chelsea 05 half boots leather     39,40,41,42,43  4000 birr
# 3                  nike fc classic         40,41,42,43  3300 birr
# 4             goupu leather comfort  39,40,41,42,43,44  3500 birr
# ...                             ...                ...        ...
# 2753           nike airmax flyknite                 42  1250 birr
# 2754                            NaN                NaN        NaN
# 2755                            NaN                NaN        NaN
# 2756                            NaN                NaN        NaN
# 2757                            NaN                NaN        NaN
#
#                                                        Address       Phone
# 0     ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል  0920238243
# 1     ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል  0920238243
# 2     ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል  0920238243
# 3     ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል  0920238243
# 4     ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል  0920238243
# ...                                                        ...         ...
# 2753                                                       NaN         NaN
# 2754                                                       NaN         NaN
# 2755                                                       NaN         NaN
# 2756                                                       NaN         NaN
# 2757                                                       NaN         NaN
#
# [2758 rows x 6 columns]

# %%
import pandas as pd
import re

# Load the CSV file
df = pd.read_csv('Pictures/2_ethio_brand_data_cleaned.csv')

# %%
import pandas as pd

# Step 1: Read the dataset into a DataFrame (assuming CSV format)
df = pd.read_csv('Pictures/2_ethio_brand_data_cleaned.csv')  # replace with your actual file path

# Step 2: Split the 'Message Text' into multiple columns using string methods
df['Product Name'] = df['Message Text'].str.split('\r\n').str[0]
df['Size'] = df['Message Text'].str.extract(r'size ([\d,]+)')
df['Price'] = df['Message Text'].str.extract(r'price (\d+ birr)')
df['Address'] = df['Message Text'].str.extract(r'አድራሻ-(.*) or call')
df['Phone'] = df['Message Text'].str.extract(r'or call (\d+)')

# Step 3: Update the DataFrame and display it
pd.set_option('display.max_colwidth', None)  # To show the full content of columns
print(df[['Product Name', 'Size', 'Price', 'Address', 'Phone']])

# Optional: Display the first few rows of the entire updated DataFrame
print(df.head())
# Out:
#                        Product Name               Size      Price  \
# 0               puma ca pro classic        40,41,42,43  3400 birr
# 1                goupu lace comfort  39,40,41,42,43,44  3500 birr
# 2     chelsea 05 half boots leather     39,40,41,42,43  4000 birr
# 3                  nike fc classic         40,41,42,43  3300 birr
# 4             goupu leather comfort  39,40,41,42,43,44  3500 birr
# ...                             ...                ...        ...
# 2753           nike airmax flyknite                 42  1250 birr
# 2754                            NaN                NaN        NaN
# 2755                            NaN                NaN        NaN
# 2756                            NaN                NaN        NaN
# 2757                            NaN                NaN        NaN
#
#                                                        Address       Phone
# 0     ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል  0920238243
# 1     ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል  0920238243
# 2     ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል  0920238243
# 3     ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል  0920238243
# 4     ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል  0920238243
# ...                                                        ...         ...
# 2753                                                       NaN         NaN
# 2754                                                       NaN         NaN
# 2755                                                       NaN         NaN
# 2756                                                       NaN         NaN
# 2757                                                       NaN         NaN
#
# [2758 rows x 5 columns]
#   Channel Title         Channel Username  Message ID  \
# 0    EthioBrand  @ethio_brand_collection      5779.0
# 1    EthioBrand  @ethio_brand_collection      5778.0
# 2    EthioBrand  @ethio_brand_collection      5777.0
# 3    EthioBrand  @ethio_brand_collection      5776.0
# 4    EthioBrand  @ethio_brand_collection      5775.0
#
#                                                                                                                                                                                                      Message Text  \
# 0               puma ca pro classic\r\nsize 40,41,42,43\r\nprice 3400 birr\r\nአድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243\r\n                                    ethiobrand
# 1          goupu lace comfort\r\nsize 39,40,41,42,43,44\r\nprice 3500 birr\r\nአድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243\r\n                                    ethiobrand
# 2  chelsea 05 half boots leather\r\nsize 39,40,41,42,43\r\nprice 4000 birr\r\nአድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243\r\n                                    ethiobrand
# 3                  nike fc classic \r\nsize 40,41,42,43\r\nprice 3300 birr\r\nአድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243\r\n                                    ethiobrand
# 4       goupu leather comfort\r\nsize 39,40,41,42,43,44\r\nprice 3500 birr\r\nአድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243\r\n                                    ethiobrand
#
#           Message Date      Price                   Product Name  \
# 0  2024-09-26 09:04:41  3400 birr            puma ca pro classic
# 1  2024-09-26 06:20:06  3500 birr             goupu lace comfort
# 2  2024-09-25 09:07:20  4000 birr  chelsea 05 half boots leather
# 3  2024-09-25 06:15:19  3300 birr               nike fc classic
# 4  2024-09-24 09:01:56  3500 birr          goupu leather comfort
#
#                 Size  \
# 0        40,41,42,43
# 1  39,40,41,42,43,44
# 2     39,40,41,42,43
# 3        40,41,42,43
# 4  39,40,41,42,43,44
#
#                                                     Address       Phone
# 0  ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል  0920238243
# 1  ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል  0920238243
# 2  ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል  0920238243
# 3  ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል  0920238243
# 4  ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል  0920238243

# %%
df
# Out:
#         Channel Title         Channel Username  Message ID  \
# 0          EthioBrand  @ethio_brand_collection      5779.0
# 1          EthioBrand  @ethio_brand_collection      5778.0
# 2          EthioBrand  @ethio_brand_collection      5777.0
# 3          EthioBrand  @ethio_brand_collection      5776.0
# 4          EthioBrand  @ethio_brand_collection      5775.0
# ...               ...                      ...         ...
# 2753       EthioBrand  @ethio_brand_collection        49.0
# 2754  made in vietnam                      NaN         NaN
# 2755          size 40                       44         NaN
# 2756  price 1250 birr                      NaN         NaN
# 2757              NaN      2017-08-03 09:58:45         NaN
#
#                                                                                                                                                                                                         Message Text  \
# 0                  puma ca pro classic\r\nsize 40,41,42,43\r\nprice 3400 birr\r\nአድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243\r\n                                    ethiobrand
# 1             goupu lace comfort\r\nsize 39,40,41,42,43,44\r\nprice 3500 birr\r\nአድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243\r\n                                    ethiobrand
# 2     chelsea 05 half boots leather\r\nsize 39,40,41,42,43\r\nprice 4000 birr\r\nአድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243\r\n                                    ethiobrand
# 3                     nike fc classic \r\nsize 40,41,42,43\r\nprice 3300 birr\r\nአድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243\r\n                                    ethiobrand
# 4          goupu leather comfort\r\nsize 39,40,41,42,43,44\r\nprice 3500 birr\r\nአድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243\r\n                                    ethiobrand
# ...                                                                                                                                                                                                              ...
# 2753                                                   nike airmax flyknite\r\nmade in vietnam\r\nsize 42\r\nprice 1250 birr\r\n,2017-08-03 09:58:46,\r\nEthioBrand,@ethio_brand_collection,48,nike airmax tailwind
# 2754                                                                                                                                                                                                             NaN
# 2755                                                                                                                                                                                                             NaN
# 2756                                                                                                                                                                                                             NaN
# 2757                                                                                                                                                                                                             NaN
#
#              Message Date      Price                   Product Name  \
# 0     2024-09-26 09:04:41  3400 birr            puma ca pro classic
# 1     2024-09-26 06:20:06  3500 birr             goupu lace comfort
# 2     2024-09-25 09:07:20  4000 birr  chelsea 05 half boots leather
# 3     2024-09-25 06:15:19  3300 birr               nike fc classic
# 4     2024-09-24 09:01:56  3500 birr          goupu leather comfort
# ...                   ...        ...                            ...
# 2753                  NaN  1250 birr           nike airmax flyknite
# 2754                  NaN        NaN                            NaN
# 2755                  NaN        NaN                            NaN
# 2756                  NaN        NaN                            NaN
# 2757                  NaN        NaN                            NaN
#
#                    Size  \
# 0           40,41,42,43
# 1     39,40,41,42,43,44
# 2        39,40,41,42,43
# 3           40,41,42,43
# 4     39,40,41,42,43,44
# ...                 ...
# 2753                 42
# 2754                NaN
# 2755                NaN
# 2756                NaN
# 2757                NaN
#
#                                                        Address       Phone
# 0     ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል  0920238243
# 1     ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል  0920238243
# 2     ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል  0920238243
# 3     ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል  0920238243
# 4     ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል  0920238243
# ...                                                        ...         ...
# 2753                                                       NaN         NaN
# 2754                                                       NaN         NaN
# 2755                                                       NaN         NaN
# 2756                                                       NaN         NaN
# 2757                                                       NaN         NaN
#
# [2758 rows x 10 columns]

# %%
# Save the cleaned DataFrame to a CSV file
df.to_csv('Pictures/lebeled_ethio_brand_data_cleaned.csv', index=False)

# %%
df = pd.read_csv('Pictures/Final_ethio_brand_data_cleaned.csv')
df.head(100)
# Out:
#    Channel Title         Channel Username  Message ID    Message Date  \
# 0     EthioBrand  @ethio_brand_collection      5779.0  9/26/2024 9:04
# 1     EthioBrand  @ethio_brand_collection      5778.0  9/26/2024 6:20
# 2     EthioBrand  @ethio_brand_collection      5777.0  9/25/2024 9:07
# 3     EthioBrand  @ethio_brand_collection      5776.0  9/25/2024 6:15
# 4     EthioBrand  @ethio_brand_collection      5775.0  9/24/2024 9:01
# ..           ...                      ...         ...             ...
# 95    EthioBrand  @ethio_brand_collection      5683.0  7/27/2024 6:06
# 96    EthioBrand  @ethio_brand_collection      5682.0  7/26/2024 9:00
# 97    EthioBrand  @ethio_brand_collection      5681.0  7/23/2024 9:00
# 98    EthioBrand  @ethio_brand_collection      5680.0  7/21/2024 6:19
# 99    EthioBrand  @ethio_brand_collection      5679.0  7/20/2024 9:01
#
#         Price                         Product Name               Size  \
# 0   3400 birr                  puma ca pro classic        40,41,42,43
# 1   3500 birr                   goupu lace comfort  39,40,41,42,43,44
# 2   4000 birr        chelsea 05 half boots leather     39,40,41,42,43
# 3   3300 birr                     nike fc classic         40,41,42,43
# 4   3500 birr                goupu leather comfort  39,40,41,42,43,44
# ..        ...                                  ...                ...
# 95  3300 birr                   nike air force lux     40,41,42,43,44
# 96  4200 birr  half crocodile double buckle boots            42,43,44
# 97  3300 birr               goupu comfort sneaker   39,40,41,42,43,44
# 98  3900 birr                   ‼ እሁድ ሁሌም ክፍት ነን ‼  39,40,41,42,43,44
# 99  2800 birr                       adidas courtic     40,41,42,43,44
#
#                                                      Address        Phone
# 0   ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል  920238243.0
# 1   ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል  920238243.0
# 2   ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል  920238243.0
# 3   ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል  920238243.0
# 4   ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል  920238243.0
# ..                                                       ...          ...
# 95  ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል  920238243.0
# 96  ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል  920238243.0
# 97  ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል  920238243.0
# 98  ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል  920238243.0
# 99  ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል  920238243.0
#
# [100 rows x 9 columns]
